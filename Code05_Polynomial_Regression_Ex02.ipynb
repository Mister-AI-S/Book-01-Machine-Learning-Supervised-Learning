# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mister-AI-S/Book-01-Machine-Learning-Supervised-Learning/blob/main/Code05_Polynomial_Regression_Ex02.ipynb)

# %% [markdown]
# ## Polynomial Regression Using scikit-learn
#
# #### In this example, we aim to predict a target variable using Polynomial Regression, a type of regression that models the relationship between the input features and the target as a polynomial function. We use SGDRegressor (Stochastic Gradient Descent Regressor) from scikit-learn to train the model. Unlike traditional regression solvers, SGD iteratively updates the model's parameters, making it particularly efficient for large datasets or when computational resources are limited.
#
# #### The process involves generating a synthetic dataset with a quadratic relationship, transforming the input features into polynomial terms, and applying stochastic gradient descent to optimize the model. By using a pipeline that includes polynomial feature transformation, feature scaling, and regression, we streamline the workflow and ensure efficient convergence of the gradient descent algorithm. This example highlights the practical application of SGD in a polynomial regression context.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Generate Synthetic Data
np.random.seed(42)
X = np.linspace(0, 10, 100).reshape(-1, 1)  # Feature: 100 points between 0 and 10
y = 3 * X**2 + 2 * X + 5 + np.random.randn(100, 1) * 10  # Quadratic relationship with noise
y = y.ravel()

# Step 2: Create Polynomial Features
degree = 2  # Polynomial degree
poly = PolynomialFeatures(degree=degree, include_bias=False)
X_poly = poly.fit_transform(X)  # Transform features to polynomial form

# Step 3: Fit the Polynomial Regression Model
model = SGDRegressor(max_iter=1000, eta0=0.0001)
model.fit(X_poly, y)
y_pred = model.predict(X_poly)

# Step 4: Evaluate the Model
mse = mean_squared_error(y, y_pred)  # Mean Squared Error
r2 = r2_score(y, y_pred)  # R-squared value

# Step 5: Visualize the Results
plt.scatter(X, y, color="blue", label="Actual Data")
plt.plot(X, y_pred, color="red", label=f"Polynomial Fit (degree={degree})")
plt.xlabel("Feature (X)")
plt.ylabel("Target (y)")
plt.title("Polynomial Regression with scikit-learn")
plt.legend()
plt.show()

# Step 6: Print Model Evaluation Metrics
print("Mean Squared Error (MSE):", mse)
print("R-squared (R^2):", r2)
print("Model Coefficients:", model.coef_)
print("Model Intercept:", model.intercept_)
# Out:
# Mean Squared Error (MSE): 97.1883619646019
# R-squared (R^2): 0.989669714178405
# Model Coefficients: [0.58386297 3.25767553]
# Model Intercept: [0.13992217]

# %%
y.shape
# Out:
# (100,)
